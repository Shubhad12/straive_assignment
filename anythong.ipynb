# %%
import pandas as pd
import numpy as np

data = {
    "transaction_id" : range(1001, 1031),
    "customer_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                    111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
                    121, 122, 123, 124, 125, 126, 127, 128, 129, 130],
    "age": [25, 34, 42, 29, 51, 37, 45, 31, 28, 56,
            39, 47, 26, 33, 41, 52, 36, 44, 30, 49,
            27, 38, 55, 32, 43, 35, 48, 29, 40, 53],
    "transaction_amount": [1200, 4500, 750, 12000, 3500, 8500, 2200, 15000, 1800, 6500,
                          3200, 9000, 1100, 4800, 7200, 13500, 2500, 5600, 1900, 8200,
                          3000, 11000, 1400, 6200, 4100, 9700, 1600, 5300, 2800, 12500],
    "processing_time_sec": [4.2, 5.1, 4.8, 7.2, 5.4, 6.1, 4.5, 8.2, 4.7, 6.8,
                            5.0, 6.4, 4.1, 5.3, 6.0, 7.5, 4.9, 5.8, 4.6, 6.7,
                            5.2, 7.0, 4.3, 6.2, 5.5, 6.5, 4.4, 5.7, 4.8, 7.3],
    "branch": ["Mumbai", "Pune", "Delhi", "Bangalore", "Mumbai", "Pune", "Delhi", "Bangalore", "Mumbai", "Pune",
               "Delhi", "Bangalore", "Mumbai", "Pune", "Delhi", "Bangalore", "Mumbai", "Pune", "Delhi", "Bangalore",
               "Mumbai", "Pune", "Delhi", "Bangalore", "Mumbai", "Pune", "Delhi", "Bangalore", "Mumbai", "Pune"],
    "channel": ["UPI", "Card", "UPI", "Card", "NetBanking", "UPI", "Card", "UPI", "NetBanking", "Card",
                "UPI", "Card", "UPI", "NetBanking", "Card", "UPI", "Card", "UPI", "NetBanking", "Card",
                "UPI", "Card", "UPI", "Card", "NetBanking", "UPI", "Card", "UPI", "NetBanking", "Card"],
    "status": ["Success", "Success", "Success", "Failed", "Success", "Success", "Failed", "Success", "Success", "Success",
               "Failed", "Success", "Success", "Success", "Failed", "Success", "Success", "Failed", "Success", "Success",
               "Success", "Failed", "Success", "Success", "Failed", "Success", "Success", "Failed", "Success", "Success"]
}

df = pd.DataFrame(data)

# %% [markdown]
# df

# %%
mean_amount = df["age"].mean()

# %%
print(mean_amount)
# Out:
# 39.166666666666664

# %%
median_amount = df["transaction_amount"].median()
print("Median Amount: ", median_amount)

mode_value = df["branch"].mode()
print(mode_value)

payment_mode = df["channel"].mode()[0]
print("Most used Payment Method: ", payment_mode)

transaction_range = df["transaction_amount"].max() - df["transaction_amount"].min()
print("Transaction Range: ", transaction_range)

variance = df["transaction_amount"].var()
print("Variance: ", variance)

std_dev = df["transaction_amount"].std()
print("Standard Deviation: ", std_dev)

df["transaction_amount"].quantile(0.25)
df["transaction_amount"].quantile(0.50)
df["transaction_amount"].quantile(0.75)
# Out:
# Median Amount:  4650.0
# 0    Mumbai
# 1      Pune
# Name: branch, dtype: str
# Most used Payment Method:  Card
# Transaction Range:  14250
# Variance:  16916750.0
# Standard Deviation:  4112.9976902497765
# np.float64(8425.0)

# %%
def transaction_segment(amount):
    if amount < 2000:
        return "Low Value"
    elif amount < 7000:
        return "Normal Value"
    else:
        return "High Value"

df["transaction_segment"] = df["transaction_amount"].apply(transaction_segment)
df[["transaction_id", "transaction_amount", "transaction_segment"]].head(30)
df["transaction_segment"].value_counts()
# Out:
# transaction_segment
# Normal Value    13
# High Value      10
# Low Value        7
# Name: count, dtype: int64
